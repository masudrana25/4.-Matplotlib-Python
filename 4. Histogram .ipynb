# %% [markdown]
# Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %%
age_1 = np.random.randint(15,30, (100)) 
age_2 = np.random.randint(15,35, (100))
# print(age_1) ; print(age_2)

# %% [markdown]
# Histogram with one data

# %%
# plt.hist(age_1) 
# bins_data = [15,20,25,30,35]
# plt.hist(age_2,color = 'red', orientation='vertical',rwidth=0.8, bins = bins_data, histtype='bar', label='Age 2' )
# plt.legend()
# plt.xticks(bins_data)
# plt.show()

# bins = 10 => total data k 10 ta same interval a vag korbey and plot korbey 10 ta alada bar a
# bins=[18,20,25,35] => range of data interval

# %%
bins_data = [15,20,25,30,35]
style.use('ggplot')
plt.figure(figsize = (10,6)) # plt.figure(figsize = (width,height))

plt.hist([age_1,age_2],color = ['red','y'], orientation='vertical', align='mid', rwidth=0.8, bins = bins_data, histtype='bar', label=['Age 1','Age 2'] )

plt.xticks(bins_data)
plt.legend()
plt.show()
